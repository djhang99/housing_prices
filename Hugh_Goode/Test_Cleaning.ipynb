# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OrdinalEncoder
from sklearn.model_selection import train_test_split
from data_preprocessing_final import initiate_data

# %%
data = pd.read_csv('Ames_HousePrice.csv', index_col=0)

# %%
train_data_linear, train_target_linear, test_data_linear, test_target_linear, train_data_tree, train_target_tree, test_data_tree, test_target_tree = initiate_data(data)

# %%
train_data_linear
# Out:
#             PID  MSZoning_C (all)  MSZoning_FV  MSZoning_I (all)  MSZoning_RH  \
# 0     923125030                 0            0                 0            0
# 1     902207150                 0            0                 0            0
# 2     902106060                 0            0                 0            0
# 3     528120030                 0            0                 0            0
# 4     908127060                 0            0                 0            0
# ...         ...               ...          ...               ...          ...
# 1921  906380030                 0            0                 0            0
# 1922  904350045                 0            0                 0            0
# 1923  905201080                 0            0                 0            0
# 1924  535301080                 0            0                 0            0
# 1925  907202160                 0            0                 0            0
#
#       MSZoning_RL  MSZoning_RM  LotShape_Reg  LandContour_HLS  \
# 0               0            0             1                0
# 1               0            1             1                0
# 2               0            1             1                0
# 3               1            0             0                0
# 4               1            0             1                0
# ...           ...          ...           ...              ...
# 1921            1            0             0                0
# 1922            1            0             0                0
# 1923            1            0             1                0
# 1924            1            0             1                0
# 1925            1            0             0                0
#
#       LandContour_Low  ...  GarageYrBlt  GarageArea  WoodDeckSF  OpenPorchSF  \
# 0                   0  ...     0.491228    0.181452    0.000000     0.000000
# 1                   0  ...     0.350877    0.322581    0.000000     0.000000
# 2                   0  ...     0.789474    0.290323    0.000000     0.503509
# 3                   0  ...     0.991228    0.622984    0.117978     0.078947
# 4                   0  ...     0.701754    0.387097    0.000000     0.000000
# ...               ...  ...          ...         ...         ...          ...
# 1921                0  ...     0.982456    0.580645    0.117978     0.052632
# 1922                0  ...     0.394737    0.155242    0.000000     0.000000
# 1923                0  ...     0.535088    0.217070    0.000000     0.000000
# 1924                0  ...     0.500000    0.161290    0.000000     0.000000
# 1925                1  ...     0.754386    0.387097    0.000000     0.000000
#
#       EnclosedPorch  3SsnPorch  ScreenPorch  TotalBath  Bsmt_Unfin_Ratio  \
# 0          0.133399        0.0     0.000000   0.083333          0.000000
# 1          0.181818        0.0     0.000000   0.000000          1.000000
# 2          0.000000        0.0     0.000000   0.166667          1.000000
# 3          0.000000        0.0     0.000000   0.333333          0.416331
# 4          0.042490        0.0     0.204082   0.166667          0.739179
# ...             ...        ...          ...        ...               ...
# 1921       0.000000        0.0     0.000000   0.166667          1.000000
# 1922       0.044466        0.0     0.000000   0.000000          0.386667
# 1923       0.000000        0.0     0.000000   0.166667          0.267742
# 1924       0.000000        0.0     0.000000   0.166667          0.794444
# 1925       0.033597        0.0     0.000000   0.166667          0.000000
#
#       TotalLivArea
# 0         0.207745
# 1         0.262882
# 2         0.497539
# 3         0.516574
# 4         0.314736
# ...            ...
# 1921      0.475222
# 1922      0.194454
# 1923      0.374303
# 1924      0.208074
# 1925      0.267804
#
# [1926 rows x 236 columns]

# %%
data
# Out:
#            PID  SalePrice  MSSubClass MSZoning  LotFrontage  LotArea LotShape  \
# 1    909176150     126000          30       RL    68.516053     7890      Reg
# 2    905476230     139500         120       RL    42.000000     4235      Reg
# 3    911128020     124900          30  C (all)    60.000000     6060      Reg
# 4    535377150     114000          70       RL    80.000000     8146      Reg
# 5    534177230     227000          60       RL    70.000000     8400      Reg
# ..         ...        ...         ...      ...          ...      ...      ...
# 759  903205040     121000          30       RL    68.516053     8854      Reg
# 760  905402060     139600          20       RL    68.516053    13680       IR
# 761  909275030     145000          90       RH    82.000000     6270      Reg
# 762  907192040     217500          60       RL    68.516053     8826      Reg
# 763  906223180     215000          60       RL    80.000000     9554       IR
#
#     LandContour LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 1           Lvl    Corner       Gtl  ...             0         0         166
# 2           Lvl    Inside       Gtl  ...             0         0           0
# 3           Lvl    Inside       Gtl  ...            42        86           0
# 4           Lvl    Corner       Gtl  ...           168         0         111
# 5           Lvl    Inside       Gtl  ...             0         0           0
# ..          ...       ...       ...  ...           ...       ...         ...
# 759         Lvl    Inside       Gtl  ...             0         0          40
# 760         Lvl   CulDSac       Gtl  ...             0         0           0
# 761         HLS    Inside       Gtl  ...             0         0           0
# 762         Lvl    Inside       Gtl  ...             0         0           0
# 763         Lvl    Inside       Gtl  ...             0         0           0
#
#         Fence  MoSold  YrSold  SaleCondition  TotalBath Bsmt_Unfin_Ratio  \
# 1    No_Fence       3    2010         Normal        2.0         0.721963
# 2    No_Fence       2    2009         Normal        3.0         0.099142
# 3    No_Fence      11    2007         Normal        1.0         0.119474
# 4    No_Fence       5    2009         Normal        1.0         1.000000
# 5    No_Fence      11    2009         Normal        3.5         0.206173
# ..        ...     ...     ...            ...        ...              ...
# 759  No_Fence       5    2009         Normal        1.0         1.000000
# 760  No_Fence       6    2009         Normal        2.0         0.000000
# 761  No_Fence       8    2007         Normal        2.0         0.716284
# 762  No_Fence       7    2007         Normal        3.5         0.146193
# 763  No_Fence       9    2006         Normal        2.5         0.510940
#
#     TotalLivArea
# 1         1712.0
# 2         2098.0
# 3         1838.0
# 4         1444.0
# 5         2475.0
# ..           ...
# 759       1904.0
# 760       1733.0
# 761       3003.0
# 762       2827.0
# 763       2688.0
#
# [2579 rows x 57 columns]
